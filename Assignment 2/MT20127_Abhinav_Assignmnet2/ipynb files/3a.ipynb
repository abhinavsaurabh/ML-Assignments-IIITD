# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import loadmat
import pandas as pd
import seaborn as sns

# %%
data1 = loadmat('dataset_2.mat')

# %%
data1
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: posix, Created on: Sat Sep 26 16:40:55 2020',
#  '__version__': '1.0',
#  '__globals__': [],
#  'samples': array([[-1.43675238, -3.9265797 ],
#         [-2.00349195, -3.54813747],
#         [-0.73024538, -4.45436567],
#         ...,
#         [-3.0936506 ,  3.44629184],
#         [ 6.43886415,  3.20051189],
#         [ 5.34614831,  3.80708106]]),
#  'labels': array([[0, 0, 0, ..., 1, 3, 3]])}

# %%
data2 = data1['samples']
mlabel = data1['labels'][0]
data3 = np.column_stack((data2,mlabel))
df = pd.DataFrame(data3)

# %%
df.columns = [0, 1,'Labels']

# %%
scatter = sns.scatterplot(data=df, x=0, y=1, hue='Labels',)
scatter.legend(loc='center left', bbox_to_anchor=(1.25, 0.5), ncol=1)
