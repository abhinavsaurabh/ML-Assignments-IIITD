# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import loadmat
import pandas as pd
import seaborn as sns

# %%
data1 = loadmat('dataset_1.mat')

# %%
data1
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: posix, Created on: Sat Sep 26 19:36:55 2020',
#  '__version__': '1.0',
#  '__globals__': [],
#  'samples': array([[ 0.03740109,  0.08861641],
#         [ 0.57277163, -0.40655467],
#         [ 0.27458618, -0.11676833],
#         ...,
#         [ 1.0391683 , -0.55422727],
#         [ 0.1355146 , -0.01042329],
#         [ 1.15340485, -0.48205253]]),
#  'labels': array([[1, 1, 1, ..., 1, 1, 1]])}

# %%
data2 = data1['samples']
mlabel = data1['labels'][0]
data3 = np.column_stack((data2,mlabel))
df = pd.DataFrame(data3)

# %%
df.columns = [0, 1,'Labels']

# %%
scatter = sns.scatterplot(data=df, x=0, y=1, hue='Labels',)
scatter.legend(loc='center left', bbox_to_anchor=(1.25, 0.5), ncol=1)
